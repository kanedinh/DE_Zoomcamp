# %% [markdown]
# Import Library

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from time import time
from tqdm import tqdm

# %% [markdown]
# Get data

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet"
df = pd.read_parquet(url, engine='pyarrow')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72         1.0                  N           186
# 1                 1.80         1.0                  N           140
# 2                 4.70         1.0                  N           236
# 3                 1.40         1.0                  N            79
# 4                 0.80         1.0                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee
# 0                         2.5          0.0
# 1                         2.5          0.0
# 2                         2.5          0.0
# 3                         2.5          0.0
# 4                         2.5          0.0
# ...                       ...          ...
# 2964619                   NaN          NaN
# 2964620                   NaN          NaN
# 2964621                   NaN          NaN
# 2964622                   NaN          NaN
# 2964623                   NaN          NaN
#
# [2964624 rows x 19 columns]

# %% [markdown]
# Connect to postgres

# %%
engine = create_engine('postgresql://root:root@localhost:5432/pg_database')
engine.connect()

# %%
query = '''
SELECT * FROM pg_database
'''

pd.read_sql(query, engine)
# Out:
#      oid      datname  datdba  encoding datlocprovider  datistemplate  \
# 0      5     postgres      10         6              c          False
# 1  16384  pg_database      10         6              c          False
# 2      1    template1      10         6              c           True
# 3      4    template0      10         6              c           True
#
#    datallowconn  dathasloginevt  datconnlimit datfrozenxid datminmxid  \
# 0          True           False            -1          731          1
# 1          True           False            -1          731          1
# 2          True           False            -1          731          1
# 3         False           False            -1          731          1
#
#    dattablespace  datcollate    datctype datlocale daticurules datcollversion  \
# 0           1663  en_US.utf8  en_US.utf8      None        None           2.36
# 1           1663  en_US.utf8  en_US.utf8      None        None           2.36
# 2           1663  en_US.utf8  en_US.utf8      None        None           2.36
# 3           1663  en_US.utf8  en_US.utf8      None        None           None
#
#                     datacl
# 0                     None
# 1                     None
# 2  {=c/root,root=CTc/root}
# 3  {=c/root,root=CTc/root}

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname    tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi       root       None       False     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %% [markdown]
# Create a table with name 'yellow_taxi'

# %%
print(pd.io.sql.get_schema(df, 'yellow_taxi', con=engine))
# Out:
# CREATE TABLE yellow_taxi (
# 	"VendorID" INTEGER,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" INTEGER,
# 	"DOLocationID" INTEGER,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %% [markdown]
# Import data that we get to postgres

# %% [markdown]
# first 5 rows

# %%
df.head(5).to_sql('yellow_taxi', engine, if_exists='replace', index=False)
# Out:
# 5

# %%
query = '''
SELECT * FROM yellow_taxi
'''

pd.read_sql(query, engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5          0.0
# 1                    1.0         18.75                   2.5          0.0
# 2                    1.0         31.30                   2.5          0.0
# 3                    1.0         17.00                   2.5          0.0
# 4                    1.0         16.10                   2.5          0.0

# %% [markdown]
# Split dataframe into chunks

# %%
chunk_size = 100000

chunks = [df.iloc[i:i+chunk_size] for i in range(5, df.shape[0], chunk_size)]

# %%
total_time = 0
i = 0
while True:
    try:
        t_start = time()
        chunks[i].to_sql('yellow_taxi', engine, if_exists='append', index=False)
        t_end = time()
        print(f'Insert the chunk number {i}. Time to write:', t_end - t_start)
    except IndexError:
        break
    i += 1
    total_time += t_end - t_start

print('Total time:', total_time)
# Out:
# Insert the chunk number 0. Time to write: 11.592065572738647
# Insert the chunk number 1. Time to write: 11.275968551635742
# Insert the chunk number 2. Time to write: 11.68914532661438
# Insert the chunk number 3. Time to write: 12.559669494628906
# Insert the chunk number 4. Time to write: 11.068636417388916
# Insert the chunk number 5. Time to write: 11.441839933395386
# Insert the chunk number 6. Time to write: 11.44556212425232
# Insert the chunk number 7. Time to write: 11.575936317443848
# Insert the chunk number 8. Time to write: 11.831672668457031
# Insert the chunk number 9. Time to write: 12.835077285766602
# Insert the chunk number 10. Time to write: 12.889684677124023
# Insert the chunk number 11. Time to write: 11.613255739212036
# Insert the chunk number 12. Time to write: 11.971116065979004
# Insert the chunk number 13. Time to write: 11.608917951583862
# Insert the chunk number 14. Time to write: 11.670017004013062
# Insert the chunk number 15. Time to write: 10.756032705307007
# Insert the chunk number 16. Time to write: 10.855443239212036
# Insert the chunk number 17. Time to write: 11.132404804229736
# Insert the chunk number 18. Time to write: 11.89656114578247
# Insert the chunk number 19. Time to write: 12.188031673431396
# Insert the chunk number 20. Time to write: 11.642403364181519
# Insert the chunk number 21. Time to write: 11.136239767074585
# Insert the chunk number 22. Time to write: 11.361419439315796
# Insert the chunk number 23. Time to write: 11.230000019073486
# Insert the chunk number 24. Time to write: 11.19968867301941
# Insert the chunk number 25. Time to write: 11.259718179702759
# Insert the chunk number 26. Time to write: 10.922112703323364
# Insert the chunk number 27. Time to write: 11.598605632781982
# Insert the chunk number 28. Time to write: 10.979901790618896
# Insert the chunk number 29. Time to write: 6.983174085617065
# Total time: 342.2103023529053

# %%
query = '''
SELECT COUNT(1) FROM yellow_taxi
'''

pd.read_sql(query, engine)
# Out:
#      count
# 0  2964624
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
